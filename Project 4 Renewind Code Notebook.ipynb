# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## Business Context

# %% [markdown]
# Renewable energy sources play an increasingly important role in the global energy mix, as the effort to reduce the environmental impact of energy production increases.
#
# Out of all the renewable energy alternatives, wind energy is one of the most developed technologies worldwide. The U.S Department of Energy has put together a guide to achieving operational efficiency using predictive maintenance practices.
#
# Predictive maintenance uses sensor information and analysis methods to measure and predict degradation and future component capability. The idea behind predictive maintenance is that failure patterns are predictable and if component failure can be predicted accurately and the component is replaced before it fails, the costs of operation and maintenance will be much lower.
#
# The sensors fitted across different machines involved in the process of energy generation collect data related to various environmental factors (temperature, humidity, wind speed, etc.) and additional features related to various parts of the wind turbine (gearbox, tower, blades, break, etc.).

# %% [markdown]
# ## Objective

# %% [markdown]
# “ReneWind” is a company working on improving the machinery/processes involved in the production of wind energy using machine learning and has collected data of generator failure of wind turbines using sensors. They have shared a ciphered version of the data, as the data collected through sensors is confidential (the type of data collected varies with companies). Data has 40 predictors, 20000 observations in the training set and 5000 in the test set.
#
# The objective is to build various classification models, tune them, and find the best one that will help identify failures so that the generators could be repaired before failing/breaking to reduce the overall maintenance cost.
# The nature of predictions made by the classification model will translate as follows:
#
# - True positives (TP) are failures correctly predicted by the model. These will result in repairing costs.
# - False negatives (FN) are real failures where there is no detection by the model. These will result in replacement costs.
# - False positives (FP) are detections where there is no failure. These will result in inspection costs.
#
# It is given that the cost of repairing a generator is much less than the cost of replacing it, and the cost of inspection is less than the cost of repair.
#
# “1” in the target variables should be considered as “failure” and “0” represents “No failure”.

# %% [markdown]
# ## Data Description

# %% [markdown]
# The data provided is a transformed version of the original data which was collected using sensors.
#
# - Train.csv - To be used for training and tuning of models.
# - Test.csv - To be used only for testing the performance of the final best model.
#
# Both the datasets consist of 40 predictor variables and 1 target variable.

# %% [markdown]
# # **Please read the instructions carefully before starting the project.**
# This is a commented Jupyter IPython Notebook file in which all the instructions and tasks to be performed are mentioned.
# * Blanks '_______' are provided in the notebook that
# needs to be filled with an appropriate code to get the correct result. With every '_______' blank, there is a comment that briefly describes what needs to be filled in the blank space.
# * Identify the task to be performed correctly, and only then proceed to write the required code.
# * Fill the code wherever asked by the commented lines like "# write your code here" or "# complete the code". Running incomplete code may throw error.
# * Please run the codes in a sequential manner from the beginning to avoid any unnecessary errors.
# * Add the results/observations (wherever mentioned) derived from the analysis in the presentation and submit the same.

# %% [markdown]
# # **Installing and Importing the necessary libraries**

# %%
# Installing the libraries with the specified version
# !pip install --no-deps tensorflow==2.19.0 scikit-learn==1.6.1 matplotlib===3.10.0 seaborn==0.13.2 numpy==2.0.2 pandas==2.2.2 -q --user --no-warn-script-location

# %% [markdown]
# **Note**:
# - After running the above cell, kindly restart the runtime (for Google Colab) or notebook kernel (for Jupyter Notebook), and run all cells sequentially from the next cell.
# - On executing the above line of code, you might see a warning regarding package dependencies. This error message can be ignored as the above code ensures that all necessary libraries and their dependencies are maintained to successfully execute the code in ***this notebook***.

# %%
# Library for data manipulation and analysis.
import pandas as pd
# Fundamental package for scientific computing.
import numpy as np
#splitting datasets into training and testing sets.
from sklearn.model_selection import train_test_split
#Imports tools for data preprocessing including label encoding, one-hot encoding, and standard scaling
from sklearn.preprocessing import LabelEncoder, OneHotEncoder,StandardScaler
#Imports a class for imputing missing values in datasets.
from sklearn.impute import SimpleImputer
#Imports the Matplotlib library for creating visualizations.
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# Imports the Seaborn library for statistical data visualization.
import seaborn as sns
# Time related functions.
import time
#Imports functions for evaluating the performance of machine learning models
from sklearn.metrics import confusion_matrix, f1_score,accuracy_score, recall_score, precision_score, classification_report
#Imports metrics from
from sklearn import metrics

#Imports the tensorflow,keras and layers.
import tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense, Input, Dropout,BatchNormalization
from tensorflow.keras import backend

# to suppress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Loading the Data**

# %%
# uncomment and run the following lines for Google Colab
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df = pd.read_csv("Train.csv")    # Complete the code to import the training data
df_test = pd.read_csv("Test.csv")    # Complete the code to import the test data

# %% [markdown]
# # **Data Overview**

# %% [markdown]
# The initial steps to get an overview of any dataset is to:
# - observe the first few rows of the dataset, to check whether the dataset has been loaded properly or not
# - get information about the number of rows and columns in the dataset
# - find out the data types of the columns to ensure that data is stored in the preferred format and the value of each property is as expected.
# - check the statistical summary of the dataset to get an overview of the numerical columns of the data

# %% [markdown]
# ## Checking the shape of the dataset

# %%
# Checking the number of rows and columns in the training data
df.shape # Complete the code to print the shape of the train data
# Out:
# (20000, 41)

# %%
# Checking the number of rows and columns in the test data
df_test.shape # Complete the code to print the shape of the test data
# Out:
# (5000, 41)

# %%
# let's create a copy of the training data
data = df.copy()

# %%
# let's create a copy of the testing  data
data_test = df_test.copy()

# %% [markdown]
# ## Displaying the first few rows of the dataset

# %%
# let's view the first 5 rows of the data
data.head() # Complete the code to view the first five rows of the train data
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -4.464606 -4.679129  3.101546  0.506130 -0.221083 -2.032511 -2.910870
# 1  3.365912  3.653381  0.909671 -1.367528  0.332016  2.358938  0.732600
# 2 -3.831843 -5.824444  0.634031 -2.418815 -1.773827  1.016824 -2.098941
# 3  1.618098  1.888342  7.046143 -1.147285  0.083080 -1.529780  0.207309
# 4 -0.111440  3.872488 -3.758361 -2.982897  3.792714  0.544960  0.205433
#
#          V8        V9       V10  ...       V32       V33        V34       V35  \
# 0  0.050714 -1.522351  3.761892  ...  3.059700 -1.690440   2.846296  2.235198
# 1 -4.332135  0.565695 -0.101080  ... -1.795474  3.032780  -2.467514  1.894599
# 2 -3.173204 -2.081860  5.392621  ... -0.257101  0.803550   4.086219  2.292138
# 3 -2.493629  0.344926  2.118578  ... -3.584425 -2.577474   1.363769  0.622714
# 4  4.848994 -1.854920 -6.220023  ...  8.265896  6.629213 -10.068689  1.222987
#
#         V36       V37       V38       V39       V40  Target
# 0  6.667486  0.443809 -2.369169  2.950578 -3.480324       0
# 1 -2.297780 -1.731048  5.908837 -0.386345  0.616242       0
# 2  5.360850  0.351993  2.940021  3.839160 -4.309402       0
# 3  5.550100 -1.526796  0.138853  3.101430 -1.277378       0
# 4 -3.229763  1.686909 -2.163896 -3.644622  6.510338       0
#
# [5 rows x 41 columns]

# %%
#viewing first 5 rows of the test data
data_test.head() # Complete the code to view the first five rows of the test data
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.613489 -3.819640  2.202302  1.300420 -1.184929 -4.495964 -1.835817
# 1  0.389608 -0.512341  0.527053 -2.576776 -1.016766  2.235112 -0.441301
# 2 -0.874861 -0.640632  4.084202 -1.590454  0.525855 -1.957592 -0.695367
# 3  0.238384  1.458607  4.014528  2.534478  1.196987 -3.117330 -0.924035
# 4  5.828225  2.768260 -1.234530  2.809264 -1.641648 -1.406698  0.568643
#
#          V8        V9       V10  ...       V32       V33       V34       V35  \
# 0  4.722989  1.206140 -0.341909  ...  2.291204 -5.411388  0.870073  0.574479
# 1 -4.405744 -0.332869  1.966794  ... -2.474936  2.493582  0.315165  2.059288
# 2  1.347309 -1.732348  0.466500  ... -1.318888 -2.997464  0.459664  0.619774
# 3  0.269493  1.322436  0.702345  ...  3.517918 -3.074085 -0.284220  0.954576
# 4  0.965043  1.918379 -2.774855  ...  1.773841 -1.501573 -2.226702  4.776830
#
#         V36       V37        V38       V39       V40  Target
# 0  4.157191  1.428093 -10.511342  0.454664 -1.448363       0
# 1  0.683859 -0.485452   5.128350  1.720744 -1.488235       0
# 2  5.631504  1.323512  -1.752154  1.808302  1.675748       0
# 3  3.029331 -1.367198  -3.412140  0.906000 -2.450889       0
# 4 -6.559698 -0.805551  -0.276007 -3.858207 -0.537694       0
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Checking the data types of the columns in the dataset

# %%
# let's check the data types of the columns in the dataset
data.info() # Complete the code to view the data types of the columns in the train data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 41 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      19982 non-null  float64
#  1   V2      19982 non-null  float64
#  2   V3      20000 non-null  float64
#  3   V4      20000 non-null  float64
#  4   V5      20000 non-null  float64
#  5   V6      20000 non-null  float64
#  6   V7      20000 non-null  float64
#  7   V8      20000 non-null  float64
#  8   V9      20000 non-null  float64
#  9   V10     20000 non-null  float64
#  10  V11     20000 non-null  float64
#  11  V12     20000 non-null  float64
#  12  V13     20000 non-null  float64
#  13  V14     20000 non-null  float64
#  14  V15     20000 non-null  float64
#  15  V16     20000 non-null  float64
#  16  V17     20000 non-null  float64
#  17  V18     20000 non-null  float64
#  18  V19     20000 non-null  float64
#  19  V20     20000 non-null  float64
#  20  V21     20000 non-null  float64
#  21  V22     20000 non-null  float64
#  22  V23     20000 non-null  float64
#  23  V24     20000 non-null  float64
#  24  V25     20000 non-null  float64
#  25  V26     20000 non-null  float64
#  26  V27     20000 non-null  float64
#  27  V28     20000 non-null  float64
#  28  V29     20000 non-null  float64
#  29  V30     20000 non-null  float64
#  30  V31     20000 non-null  float64
#  31  V32     20000 non-null  float64
#  32  V33     20000 non-null  float64
#  33  V34     20000 non-null  float64
#  34  V35     20000 non-null  float64
#  35  V36     20000 non-null  float64
#  36  V37     20000 non-null  float64
#  37  V38     20000 non-null  float64
#  38  V39     20000 non-null  float64
#  39  V40     20000 non-null  float64
#  40  Target  20000 non-null  int64
# dtypes: float64(40), int64(1)
# memory usage: 6.3 MB

# %% [markdown]
# - Converting Target column to float

# %%
data['Target'] = data['Target'].astype(float)

# %% [markdown]
# Now checking for test data

# %%
data_test.info() # Complete the code to view the data types of the columns in the test data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 41 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      4995 non-null   float64
#  1   V2      4994 non-null   float64
#  2   V3      5000 non-null   float64
#  3   V4      5000 non-null   float64
#  4   V5      5000 non-null   float64
#  5   V6      5000 non-null   float64
#  6   V7      5000 non-null   float64
#  7   V8      5000 non-null   float64
#  8   V9      5000 non-null   float64
#  9   V10     5000 non-null   float64
#  10  V11     5000 non-null   float64
#  11  V12     5000 non-null   float64
#  12  V13     5000 non-null   float64
#  13  V14     5000 non-null   float64
#  14  V15     5000 non-null   float64
#  15  V16     5000 non-null   float64
#  16  V17     5000 non-null   float64
#  17  V18     5000 non-null   float64
#  18  V19     5000 non-null   float64
#  19  V20     5000 non-null   float64
#  20  V21     5000 non-null   float64
#  21  V22     5000 non-null   float64
#  22  V23     5000 non-null   float64
#  23  V24     5000 non-null   float64
#  24  V25     5000 non-null   float64
#  25  V26     5000 non-null   float64
#  26  V27     5000 non-null   float64
#  27  V28     5000 non-null   float64
#  28  V29     5000 non-null   float64
#  29  V30     5000 non-null   float64
#  30  V31     5000 non-null   float64
#  31  V32     5000 non-null   float64
#  32  V33     5000 non-null   float64
#  33  V34     5000 non-null   float64
#  34  V35     5000 non-null   float64
#  35  V36     5000 non-null   float64
#  36  V37     5000 non-null   float64
#  37  V38     5000 non-null   float64
#  38  V39     5000 non-null   float64
#  39  V40     5000 non-null   float64
#  40  Target  5000 non-null   int64
# dtypes: float64(40), int64(1)
# memory usage: 1.6 MB

# %% [markdown]
# Converting Target to float

# %%
data_test['Target'] = data_test['Target'].astype(float)

# %% [markdown]
# ## Checking for duplicate values

# %%
# let's check for duplicate values in the data
data.duplicated().sum() # Complete the code to check for duplicate values in the train data
# Out:
# np.int64(0)

# %% [markdown]
# ## Checking for missing values

# %%
# let's check for missing values in the data
data.isnull().sum()
# Out:
# V1        18
# V2        18
# V3         0
# V4         0
# V5         0
# V6         0
# V7         0
# V8         0
# V9         0
# V10        0
# V11        0
# V12        0
# V13        0
# V14        0
# V15        0
# V16        0
# V17        0
# V18        0
# V19        0
# V20        0
# V21        0
# V22        0
# V23        0
# V24        0
# V25        0
# V26        0
# V27        0
# V28        0
# V29        0
# V30        0
# V31        0
# V32        0
# V33        0
# V34        0
# V35        0
# V36        0
# V37        0
# V38        0
# V39        0
# V40        0
# Target     0
# dtype: int64

# %%
# let's check for missing values in the test data
data_test.isnull().sum() #
# Out:
# V1        5
# V2        6
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# V29       0
# V30       0
# V31       0
# V32       0
# V33       0
# V34       0
# V35       0
# V36       0
# V37       0
# V38       0
# V39       0
# V40       0
# Target    0
# dtype: int64

# %% [markdown]
# ## Statistical summary of the dataset

# %%
# let's view the statistical summary of the numerical columns in the data
data.describe().T # Complete the code to view the statistical summary of the train data
# Out:
#           count      mean       std        min       25%       50%       75%  \
# V1      19982.0 -0.271996  3.441625 -11.876451 -2.737146 -0.747917  1.840112
# V2      19982.0  0.440430  3.150784 -12.319951 -1.640674  0.471536  2.543967
# V3      20000.0  2.484699  3.388963 -10.708139  0.206860  2.255786  4.566165
# V4      20000.0 -0.083152  3.431595 -15.082052 -2.347660 -0.135241  2.130615
# V5      20000.0 -0.053752  2.104801  -8.603361 -1.535607 -0.101952  1.340480
# V6      20000.0 -0.995443  2.040970 -10.227147 -2.347238 -1.000515  0.380330
# V9       8.137580
# V10      8.108472
# V11     11.826433
# V12     15.080698
# V13     15.419616
# V14      5.670664
# V15     12.246455
# V16     13.583212
# V17     16.756432
# V18     13.179863
# V19     13.237742
# V20     16.052339
# V21     13.840473
# V22      7.409856
# V23     14.458734
# V24     17.163291
# V25      8.223389
# V26     16.836410
# V27     17.560404
# V28      6.527643
# V29     10.722055
# V30     12.505812
# V31     17.255090
# V32     23.633187
# V33     16.692486
# V34     14.358213
# V35     15.291065
# V36     19.329576
# V37      7.467006
# V38     15.289923
# V39      7.759877
# V40     10.654265
# Target   1.000000

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ## Univariate analysis

# %%
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data= data, x= feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %% [markdown]
# ### Variables V1 to V29

# %%
for feature in df.columns:
    histogram_boxplot(df, feature, figsize=(12, 7), kde=False, bins=None)

# %% [markdown]
# ### Checking the distrubution of Target variable

# %%
# For train data
df["Target"].value_counts(1)
# Out:
# Target
# 0    0.9445
# 1    0.0555
# Name: proportion, dtype: float64

# %%
# For test data
df_test["Target"].value_counts(1) # Complete the code to display the proportion of the target variable in the test data
# Out:
# Target
# 0    0.9436
# 1    0.0564
# Name: proportion, dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Correlation Check

# %%
cols_list = df.select_dtypes(include=np.number).columns.tolist()
cols_list.remove("Target")

plt.figure(figsize=(25, 25))
sns.heatmap(
    df[cols_list].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral"
)
plt.show()

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ## Data Preparation for Modeling

# %%
# Dividing train data into X and y
X = data.drop(columns = ["Target"] , axis=1) # Complete the code to remove the column named 'Target'
y = data["Target"] # Complete the code to select the column named 'Target'

# %% [markdown]
# **Since we already have a separate test set, we don't need to divide data into train, valiation and test**

# %%
# Splitting data into training and validation set:

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.25, random_state=1, stratify=y # Complete the code to define the test size
)

# %%
# Checking the number of rows and columns in the X_train data
X_train.shape
# Out:
# (15000, 40)

# %%
# Checking the number of rows and columns in the X_val data
X_val.shape
# Out:
# (5000, 40)

# %%
# Dividing test data into X_test and y_test
X_test = data_test.drop(columns = ['Target'] , axis= 1) # Complete the code to remove the target column
y_test = data_test["Target"] # Complete the code to select the target column

# %%
# Checking the number of rows and columns in the X_test data
X_test.shape
# Out:
# (5000, 40)

# %% [markdown]
# ## Missing Value Imputation

# %% [markdown]
# - There were few missing values in V1 and V2, we will impute them using the median.
# - And to avoid data leakage we will impute missing values after splitting train data into train and validation sets.

# %%
imputer = SimpleImputer(strategy="median")

# %%
# Fit and transform the train data
X_train = pd.DataFrame(imputer.fit_transform(X_train), columns=X_train.columns)

# Transform the validation data
X_val = pd.DataFrame(imputer.transform(X_val), columns=X_train.columns)    # Complete the code to impute missing values in the validation set while accounting for data leakage

# Transform the test data
X_test = pd.DataFrame(imputer.transform(X_test), columns=X_train.columns)    # Complete the code to impute missing values in the test set while accounting for data leakage

# %%
# Checking that no column has missing values in train or test sets
print(X_train.isna().sum())
print("-" * 30)
print(X_val.isna().sum())
print("-" * 30)
print(X_test.isna().sum())
# Out:
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64
# ------------------------------
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64
# ------------------------------
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## Model Evaluation Criterion

# %% [markdown]
# - Write down the metric of choice with rationale here

# %% [markdown]
# **We are now done with pre-processing and evaluation criterion, so let's start building the model.**

# %% [markdown]
# ## Utility Functions

# %%
def plot(history, name):
    """
    Function to plot loss/accuracy

    history: an object which stores the metrics and losses.
    name: can be one of Loss or Accuracy
    """
    fig, ax = plt.subplots() #Creating a subplot with figure and axes.
    plt.plot(history.history[name]) #Plotting the train accuracy or train loss
    plt.plot(history.history['val_'+name]) #Plotting the validation accuracy or validation loss

    plt.title('Model ' + name.capitalize()) #Defining the title of the plot.
    plt.ylabel(name.capitalize()) #Capitalizing the first letter.
    plt.xlabel('Epoch') #Defining the label for the x-axis.
    fig.legend(['Train', 'Validation'], loc="outside right upper") #Defining the legend, loc controls the position of the legend.

# %%
# defining a function to compute different metrics to check performance of a classification model built using statsmodels
def model_performance_classification(
    model, predictors, target, threshold=0.5
):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    threshold: threshold for classifying the observation as class 1
    """

    # checking which probabilities are greater than threshold
    pred = model.predict(predictors) > threshold
    # pred_temp = model.predict(predictors) > threshold
    # # rounding off the above values to get classes
    # pred = np.round(pred_temp)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred, average='macro')  # to compute Recall
    precision = precision_score(target, pred, average='macro')  # to compute Precision
    f1 = f1_score(target, pred, average='macro')  # to compute F1-score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {"Accuracy": acc, "Recall": recall, "Precision": precision, "F1 Score": f1,}, index = [0]
    )

    return df_perf

# %% [markdown]
# ## Initial Model Building (Model 0)

# %% [markdown]
# - Let's start with a neural network consisting of
#   - just one hidden layer of 7 neurons respectively
#   - activation function of ReLU.
#   - SGD as the optimizer

# %%
# defining the batch size and # epochs upfront as we'll be using the same values for all models
epochs = 50    # Complete the code to enter the number of epochs to be used in all models
batch_size = 32    # Complete the code to enter the batch size to be used in all models

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - Recall: 0.8288 - loss: 0.0540 - val_Recall: 0.8058 - val_loss: 0.0685
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7928 - loss: 0.0594 - val_Recall: 0.8129 - val_loss: 0.0686
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8038 - loss: 0.0525 - val_Recall: 0.8058 - val_loss: 0.0677
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8103 - loss: 0.0545 - val_Recall: 0.8058 - val_loss: 0.0680
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8218 - loss: 0.0575 - val_Recall: 0.8058 - val_loss: 0.0680
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8028 - loss: 0.0570 - val_Recall: 0.8129 - val_loss: 0.0681
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7854 - loss: 0.0584 - val_Recall: 0.8129 - val_loss: 0.0679
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8076 - loss: 0.0528 - val_Recall: 0.8165 - val_loss: 0.0676
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8202 - loss: 0.0534 - val_Recall: 0.8165 - val_loss: 0.0677
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8179 - loss: 0.0541 - val_Recall: 0.8237 - val_loss: 0.0674
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8332 - loss: 0.0538 - val_Recall: 0.8094 - val_loss: 0.0673
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8346 - loss: 0.0513 - val_Recall: 0.8094 - val_loss: 0.0677
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8193 - loss: 0.0534 - val_Recall: 0.8237 - val_loss: 0.0674
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8262 - loss: 0.0512 - val_Recall: 0.8237 - val_loss: 0.0673
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7985 - loss: 0.0545 - val_Recall: 0.8237 - val_loss: 0.0674
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8125 - loss: 0.0545 - val_Recall: 0.8129 - val_loss: 0.0671

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  58.282419204711914

# %%
plot(history,'loss')

# %%
model_0_train_perf = model_performance_classification(model_0, X_train, y_train)
model_0_train_perf
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.987733  0.905262   0.974658  0.936872

# %%
model_0_val_perf = model_performance_classification(model_0,X_val,y_val)
model_0_val_perf
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0     0.987  0.905098   0.967342   0.93371

# %% [markdown]
# Let's check the classification reports.

# %%
y_train_pred_0 = model_0.predict(X_train)
y_val_pred_0 = model_0.predict(X_val)
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
print("Classification Report - Train data Model_0",end="\n\n")
cr_train_model_0 = classification_report(y_train,y_train_pred_0>0.5)
print(cr_train_model_0)
# Out:
# Classification Report - Train data Model_0
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     14168
#            1       0.96      0.78      0.86       832
#
#     accuracy                           0.99     15000
#    macro avg       0.97      0.89      0.93     15000
# weighted avg       0.99      0.99      0.99     15000

# %%
print("Classification Report - Validation data Model_0",end="\n\n")
cr_val_model_0 = classification_report(y_val,y_val_pred_0>0.5)
print(cr_val_model_0)
# Out:
# Classification Report - Validation data Model_0
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      4722
#            1       0.95      0.80      0.87       278
#
#     accuracy                           0.99      5000
#    macro avg       0.97      0.90      0.93      5000
# weighted avg       0.99      0.99      0.99      5000

# %% [markdown]
# # **Model Performance Improvement**

# %% [markdown]
# ## Model 1

# %% [markdown]
# - Let's try adding another layer to see if we can improve our model's performance.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
model_1 = Sequential()
model_1.add(Dense( 7 ,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_1.add(Dense( 14,activation="relu")) # Complete the code to define the number of neurons and activation function
model_1.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 7)              │           287 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 14)             │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            15 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 414 (1.62 KB)
#  Trainable params: 414 (1.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
# model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_1.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.2558 - loss: 0.2943 - val_Recall: 0.2482 - val_loss: 0.1556
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.3459 - loss: 0.1491 - val_Recall: 0.3885 - val_loss: 0.1261
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.4793 - loss: 0.1121 - val_Recall: 0.5576 - val_loss: 0.1113
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.5646 - loss: 0.1048 - val_Recall: 0.5647 - val_loss: 0.1025
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7668 - loss: 0.0631 - val_Recall: 0.8022 - val_loss: 0.0686
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7766 - loss: 0.0624 - val_Recall: 0.8022 - val_loss: 0.0690
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7974 - loss: 0.0550 - val_Recall: 0.7986 - val_loss: 0.0684
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7857 - loss: 0.0580 - val_Recall: 0.7986 - val_loss: 0.0685
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7989 - loss: 0.0540 - val_Recall: 0.7950 - val_loss: 0.0686
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8022 - loss: 0.0559 - val_Recall: 0.8094 - val_loss: 0.0691
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8077 - loss: 0.0532 - val_Recall: 0.8165 - val_loss: 0.0688

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  64.10620212554932

# %%
plot(history,'loss')

# %%
model_1_train_perf = model_performance_classification(model_1,X_train,y_train)
model_1_train_perf
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.987667  0.901267   0.978385  0.936016

# %%
model_1_val_perf = model_performance_classification(model_1,X_val,y_val)
model_1_val_perf
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9872  0.906897    0.96756  0.934849

# %%
y_train_pred_1 = model_1.predict(X_train)
y_val_pred_1 = model_1.predict(X_val)
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
print("Classification Report - Train data Model_1", end="\n\n")
cr_train_model_1 = classification_report(y_train,y_train_pred_1 > 0.5)
print(cr_train_model_1)
# Out:
# Classification Report - Train data Model_1
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99     14168
#          1.0       0.97      0.80      0.88       832
#
#     accuracy                           0.99     15000
#    macro avg       0.98      0.90      0.94     15000
# weighted avg       0.99      0.99      0.99     15000

# %%
print("Classification Report - Validation data Model_1", end="\n\n")
cr_val_model_1 = classification_report(y_val,y_val_pred_1 > 0.5)
print(cr_val_model_1)
# Out:
# Classification Report - Validation data Model_1
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      4722
#          1.0       0.95      0.82      0.88       278
#
#     accuracy                           0.99      5000
#    macro avg       0.97      0.91      0.93      5000
# weighted avg       0.99      0.99      0.99      5000

# %% [markdown]
# ## Model 2

# %% [markdown]
# To introduce Regularization in our model, let's set the dropout to 50% after adding the first hidden layer. This step will randomly drop 50% of the neurons before proceeding to the next layer, reducing overfitting.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
from tensorflow.keras.layers import Dropout
model_2 = Sequential()
model_2.add(Dense(32,activation="relu",input_dim=X_train.shape[1]))  # Complete the code to define the number of neurons and activation function
model_2.add(Dropout(.50)) # Complete the code to define the dropout rate
model_2.add(Dense(16,activation = "relu")) # Complete the code to define the number of neurons and activation function
model_2.add(Dense(8,activation = "relu")) # Complete the code to define the number of neurons and activation function
model_2.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_2.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 32)             │         1,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,985 (7.75 KB)
#  Trainable params: 1,985 (7.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
# model_2.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_2.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_2.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_2.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_2.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.0403 - loss: 0.3420 - val_Recall: 0.0540 - val_loss: 0.1634
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.0798 - loss: 0.1740 - val_Recall: 0.3058 - val_loss: 0.1331
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.2678 - loss: 0.1499 - val_Recall: 0.4640 - val_loss: 0.1170
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.3495 - loss: 0.1390 - val_Recall: 0.5360 - val_loss: 0.1038
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.4301 - loss: 0.1320 - val_Recall: 0.6079 - val_loss: 0.0961
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.4787 - loss: 0.1274 - val_Recall: 0.6331 - val_loss: 0.0910
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.4973 - loss: 0.1173 - val_Recall: 0.6871 - val_loss: 0.0861
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.5471 - loss: 0.1059 - val_Recall: 0.7230 - val_loss: 0.0822
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.5881 - loss: 0.1098 - val_Recall: 0.7302 - val_loss: 0.0807
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.5614 - loss: 0.0999 - val_Recall: 0.7374 - val_loss: 0.0782
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.
# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  65.1871964931488

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_2 on training and validation data respectively.

# %%
model_2_train_perf = model_performance_classification(model_2,X_train,y_train)
model_2_train_perf
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9868  0.884404   0.988668  0.929547

# %%
model_2_val_perf = model_performance_classification(model_2,X_val,y_val)
model_2_val_perf
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9884  0.899069   0.989673  0.939178

# %%
y_train_pred_2 = model_2.predict(X_train)
y_val_pred_2 = model_2.predict(X_val)
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Lets check the classification report of model_2 on training and validation data respectively.

# %%
print("Classification Report - Train data Model_2", end="\n\n")
cr_train_model_2 = classification_report(y_train,y_train_pred_2 > 0.5)
print(cr_train_model_2)
# Out:
# Classification Report - Train data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99     14168
#          1.0       0.99      0.77      0.87       832
#
#     accuracy                           0.99     15000
#    macro avg       0.99      0.88      0.93     15000
# weighted avg       0.99      0.99      0.99     15000

# %%
print("Classification Report - Validation data Model_2", end="\n\n")
cr_val_model_2 = classification_report(y_val , y_val_pred_2 > 0.5)
print(cr_val_model_2)
# Out:
# Classification Report - Validation data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      4722
#          1.0       0.99      0.80      0.88       278
#
#     accuracy                           0.99      5000
#    macro avg       0.99      0.90      0.94      5000
# weighted avg       0.99      0.99      0.99      5000

# %% [markdown]
# ## Model 3

# %% [markdown]
# As we have are dealing with an imbalance in class distribution, we should also be using class weights to allow the model to give proportionally more importance to the minority class.

# %%
# Calculate class weights for imbalanced dataset
cw = (y_train.shape[0]) / np.bincount(y_train.astype(int)) # Convert y_train to integers

# Create a dictionary mapping class indices to their respective class weights
cw_dict = {}
for i in range(cw.shape[0]):
    cw_dict[i] = cw[i]

cw_dict
# Out:
# {0: np.float64(1.0587238848108413), 1: np.float64(18.028846153846153)}

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
model_3 = Sequential()
model_3.add(Dense(64,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_3.add(Dropout(.50)) # Complete the code to define the dropout rate
model_3.add(Dense(32,activation="relu")) # Complete the code to define the number of neurons and activation function
model_3.add(Dense(16, activation = "relu")) # Complete the code to define the number of neurons and activation function
model_3.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_3.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │         2,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,249 (20.50 KB)
#  Trainable params: 5,249 (20.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
# model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_3.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs,class_weight=cw_dict)
end=time.time()
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7995 - loss: 1.0753 - val_Recall: 0.8669 - val_loss: 0.2286
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8565 - loss: 0.6712 - val_Recall: 0.8597 - val_loss: 0.1501
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8685 - loss: 0.5917 - val_Recall: 0.8741 - val_loss: 0.2296
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8721 - loss: 0.5497 - val_Recall: 0.8705 - val_loss: 0.1654
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8768 - loss: 0.5390 - val_Recall: 0.8741 - val_loss: 0.1228
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8836 - loss: 0.5000 - val_Recall: 0.8705 - val_loss: 0.1729
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8969 - loss: 0.4365 - val_Recall: 0.8741 - val_loss: 0.1476
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9028 - loss: 0.4397 - val_Recall: 0.8741 - val_loss: 0.1718
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9002 - loss: 0.4319 - val_Recall: 0.8849 - val_loss: 0.1644
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8726 - loss: 0.4571 - val_Recall: 0.8813 - val_loss: 0.1630
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8845 - loss: 0.4222 - val_Recall: 0.8741 - val_loss: 0.1564
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8969 - loss: 0.3978 - val_Recall: 0.8741 - val_loss: 0.1608
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8945 - loss: 0.4081 - val_Recall: 0.8741 - val_loss: 0.1149
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9908  0.956099   0.956099  0.956099

# %%
model_3_val_perf = model_performance_classification(model_3,X_val,y_val)
model_3_val_perf
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9914  0.944667   0.971931  0.957839

# %%
y_train_pred_3 = model_3.predict(X_train)
y_val_pred_3 = model_3.predict(X_val)
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Lets check the classification report of model_3 on training and validation data respectively.

# %%
print("Classification Report - Train data Model_3", end="\n\n")
cr_train_model_3 = classification_report(y_train,y_train_pred_3 > 0.5)
print(cr_train_model_3)
# Out:
# Classification Report - Train data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14168
#          1.0       0.92      0.92      0.92       832
#
#     accuracy                           0.99     15000
#    macro avg       0.96      0.96      0.96     15000
# weighted avg       0.99      0.99      0.99     15000

# %%
print("Classification Report - Validation data Model_3", end="\n\n")
cr_val_model_3 = classification_report(y_val,y_val_pred_3 > 0.5)
print(cr_val_model_3)
# Out:
# Classification Report - Validation data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      4722
#          1.0       0.95      0.89      0.92       278
#
#     accuracy                           0.99      5000
#    macro avg       0.97      0.94      0.96      5000
# weighted avg       0.99      0.99      0.99      5000

# %% [markdown]
# ## Model 4

# %% [markdown]
# Since we have used only SGD optimizer till now, let's use another kind of optimizer and observe its impact on the model performmance.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
model_4 = Sequential()
model_4.add(Dense(7,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_4.add(Dense(14,activation="relu")) # Complete the code to define the number of neurons and activation function
model_4.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_4.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_17 (Dense)                │ (None, 7)              │           287 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 14)             │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │            15 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 414 (1.62 KB)
#  Trainable params: 414 (1.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam()    # defining Adam as the optimizer to be used
# model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_4.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.0414 - loss: 0.1791 - val_Recall: 0.4568 - val_loss: 0.1125
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.4361 - loss: 0.1071 - val_Recall: 0.6259 - val_loss: 0.0942
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.6328 - loss: 0.0854 - val_Recall: 0.6691 - val_loss: 0.0829
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.6842 - loss: 0.0684 - val_Recall: 0.7194 - val_loss: 0.0754
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7539 - loss: 0.0670 - val_Recall: 0.7590 - val_loss: 0.0699
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7717 - loss: 0.0582 - val_Recall: 0.7842 - val_loss: 0.0674
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.8305 - loss: 0.0535 - val_Recall: 0.7986 - val_loss: 0.0652
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8148 - loss: 0.0531 - val_Recall: 0.8022 - val_loss: 0.0620
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8180 - loss: 0.0513 - val_Recall: 0.8237 - val_loss: 0.0629
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8445 - loss: 0.0468 - val_Recall: 0.8201 - val_loss: 0.0612
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8223 - loss: 0.0466 - val_Recall: 0.8345 - val_loss: 0.0603
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8233 - loss: 0.0518 - val_Recall: 0.8237 - val_loss: 0.0610
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8281 - loss: 0.0523 - val_Recall: 0.8273 - val_loss: 0.0609
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8450 - loss: 0.0450 - val_Recall: 0.8345 - val_loss: 0.0604
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8397 - loss: 0.0451 - val_Recall: 0.8273 - val_loss: 0.0615
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8353 - loss: 0.0476 - val_Recall: 0.8165 - val_loss: 0.0624
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8404 - loss: 0.0433 - val_Recall: 0.8273 - val_loss: 0.0621
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8520 - loss: 0.0465 - val_Recall: 0.8381 - val_loss: 0.0624
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8598 - loss: 0.0428 - val_Recall: 0.8309 - val_loss: 0.0605
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8744 - loss: 0.0390 - val_Recall: 0.8273 - val_loss: 0.0617
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8513 - loss: 0.0424 - val_Recall: 0.8381 - val_loss: 0.0613
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8497 - loss: 0.0418 - val_Recall: 0.8417 - val_loss: 0.0608
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8410 - loss: 0.0461 - val_Recall: 0.8417 - val_loss: 0.0612
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8829 - loss: 0.0357 - val_Recall: 0.8525 - val_loss: 0.0584
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8676 - loss: 0.0414 - val_Recall: 0.8273 - val_loss: 0.0612
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8609 - loss: 0.0380 - val_Recall: 0.8597 - val_loss: 0.0610
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - Recall: 0.8637 - loss: 0.0405 - val_Recall: 0.8309 - val_loss: 0.0599
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8528 - loss: 0.0464 - val_Recall: 0.8345 - val_loss: 0.0624
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8827 - loss: 0.0361 - val_Recall: 0.8273 - val_loss: 0.0603
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8463 - loss: 0.0439 - val_Recall: 0.8597 - val_loss: 0.0612
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8914 - loss: 0.0382 - val_Recall: 0.8453 - val_loss: 0.0599
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8714 - loss: 0.0416 - val_Recall: 0.8417 - val_loss: 0.0597
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8749 - loss: 0.0353 - val_Recall: 0.8561 - val_loss: 0.0613
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8677 - loss: 0.0422 - val_Recall: 0.8597 - val_loss: 0.0603
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8776 - loss: 0.0418 - val_Recall: 0.8633 - val_loss: 0.0614
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8989 - loss: 0.0349 - val_Recall: 0.8705 - val_loss: 0.0606
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8719 - loss: 0.0427 - val_Recall: 0.8561 - val_loss: 0.0601
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8751 - loss: 0.0382 - val_Recall: 0.8741 - val_loss: 0.0592
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8939 - loss: 0.0398 - val_Recall: 0.8561 - val_loss: 0.0646
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8765 - loss: 0.0390 - val_Recall: 0.8633 - val_loss: 0.0600
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8824 - loss: 0.0374 - val_Recall: 0.8633 - val_loss: 0.0588
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8877 - loss: 0.0376 - val_Recall: 0.8705 - val_loss: 0.0598
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8991 - loss: 0.0348 - val_Recall: 0.8741 - val_loss: 0.0589
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9036 - loss: 0.0353 - val_Recall: 0.8741 - val_loss: 0.0590
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9050 - loss: 0.0322 - val_Recall: 0.8669 - val_loss: 0.0580
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8828 - loss: 0.0376 - val_Recall: 0.8669 - val_loss: 0.0593
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - Recall: 0.9050 - loss: 0.0316 - val_Recall: 0.8597 - val_loss: 0.0593
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8829 - loss: 0.0368 - val_Recall: 0.8597 - val_loss: 0.0607
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8932 - loss: 0.0336 - val_Recall: 0.8705 - val_loss: 0.0579
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9045 - loss: 0.0318 - val_Recall: 0.8669 - val_loss: 0.0584

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  65.25914096832275

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance ofr model_4 on training and validation data respectively

# %%
model_4_train_perf = model_performance_classification(model_4,X_train,y_train)
model_4_train_perf
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy   Recall  Precision  F1 Score
# 0    0.9938  0.95203   0.988098  0.969282

# %%
model_4_val_perf = model_performance_classification(model_4,X_val,y_val)
model_4_val_perf
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9912  0.932712   0.981994  0.955853

# %%
y_train_pred_4 = model_4.predict(X_train)
y_val_pred_4 = model_4.predict(X_val)
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Lets check the classification report of model_4 on raining and validation data respectively.

# %%
print("Classification Report - Train data Model_4", end="\n\n")
cr_train_model_4 = classification_report(y_train,y_train_pred_4 > 0.5)
print(cr_train_model_4)
# Out:
# Classification Report - Train data Model_4
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     14168
#          1.0       0.98      0.91      0.94       832
#
#     accuracy                           0.99     15000
#    macro avg       0.99      0.95      0.97     15000
# weighted avg       0.99      0.99      0.99     15000

# %%
print("Classification Report - Validation data Model_4", end="\n\n")
cr_val_model_4 = classification_report(y_val,y_val_pred_4 > 0.5)
print(cr_val_model_4)
# Out:
# Classification Report - Validation data Model_4
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      4722
#          1.0       0.97      0.87      0.92       278
#
#     accuracy                           0.99      5000
#    macro avg       0.98      0.93      0.96      5000
# weighted avg       0.99      0.99      0.99      5000

# %% [markdown]
# ## Model 5

# %% [markdown]
# This time we will add more layers and dropout while using a different optimizer.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
from tensorflow.keras.layers import Dropout
model_5 = Sequential()
model_5.add(Dense(64,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_5.add(Dropout(.50)) #Complete the code to define the dropout rate
model_5.add(Dense(32,activation="relu")) # Complete the code to define the number of neurons and activation function
model_5.add(Dense(16, activation = "relu")) # Complete the code to define the number of neurons and activation function
model_5.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons and activation function

# %%
model_5.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 64)             │         2,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,249 (20.50 KB)
#  Trainable params: 5,249 (20.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam()    # defining Adam as the optimizer to be used
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_5.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.2071 - loss: 0.2142 - val_Recall: 0.6547 - val_loss: 0.0921
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.6262 - loss: 0.1018 - val_Recall: 0.7770 - val_loss: 0.0756
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.6922 - loss: 0.0828 - val_Recall: 0.7554 - val_loss: 0.0663
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7532 - loss: 0.0738 - val_Recall: 0.8417 - val_loss: 0.0605
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7744 - loss: 0.0692 - val_Recall: 0.8273 - val_loss: 0.0584
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7758 - loss: 0.0612 - val_Recall: 0.8309 - val_loss: 0.0609
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7807 - loss: 0.0660 - val_Recall: 0.8417 - val_loss: 0.0557
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - Recall: 0.8284 - loss: 0.0607 - val_Recall: 0.8417 - val_loss: 0.0564
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7974 - loss: 0.0610 - val_Recall: 0.8561 - val_loss: 0.0563
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8036 - loss: 0.0549 - val_Recall: 0.8309 - val_loss: 0.0562
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8198 - loss: 0.0541 - val_Recall: 0.8525 - val_loss: 0.0533
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8500 - loss: 0.0507 - val_Recall: 0.8525 - val_loss: 0.0547
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8390 - loss: 0.0496 - val_Recall: 0.8597 - val_loss: 0.0557
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8527 - loss: 0.0446 - val_Recall: 0.8417 - val_loss: 0.0567
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8478 - loss: 0.0469 - val_Recall: 0.8525 - val_loss: 0.0549
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8131 - loss: 0.0532 - val_Recall: 0.8597 - val_loss: 0.0549
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - Recall: 0.8473 - loss: 0.0500 - val_Recall: 0.8561 - val_loss: 0.0563
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8375 - loss: 0.0486 - val_Recall: 0.8525 - val_loss: 0.0551
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8501 - loss: 0.0495 - val_Recall: 0.8597 - val_loss: 0.0543
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8342 - loss: 0.0522 - val_Recall: 0.8489 - val_loss: 0.0542
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8536 - loss: 0.0426 - val_Recall: 0.8417 - val_loss: 0.0573
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8399 - loss: 0.0475 - val_Recall: 0.8597 - val_loss: 0.0559
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8655 - loss: 0.0463 - val_Recall: 0.8633 - val_loss: 0.0571
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8514 - loss: 0.0460 - val_Recall: 0.8741 - val_loss: 0.0551
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.8394 - loss: 0.0459 - val_Recall: 0.8561 - val_loss: 0.0553
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8482 - loss: 0.0457 - val_Recall: 0.8705 - val_loss: 0.0554
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8585 - loss: 0.0499 - val_Recall: 0.8561 - val_loss: 0.0539
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8669 - loss: 0.0413 - val_Recall: 0.8669 - val_loss: 0.0552
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8732 - loss: 0.0395 - val_Recall: 0.8705 - val_loss: 0.0548
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8470 - loss: 0.0438 - val_Recall: 0.8633 - val_loss: 0.0572
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8307 - loss: 0.0479 - val_Recall: 0.8669 - val_loss: 0.0578
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8681 - loss: 0.0441 - val_Recall: 0.8417 - val_loss: 0.0569
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8586 - loss: 0.0419 - val_Recall: 0.8597 - val_loss: 0.0590
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8800 - loss: 0.0399 - val_Recall: 0.8669 - val_loss: 0.0558
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8691 - loss: 0.0397 - val_Recall: 0.8669 - val_loss: 0.0554
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8395 - loss: 0.0473 - val_Recall: 0.8453 - val_loss: 0.0569
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8412 - loss: 0.0457 - val_Recall: 0.8669 - val_loss: 0.0555
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8821 - loss: 0.0432 - val_Recall: 0.8633 - val_loss: 0.0549
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8886 - loss: 0.0362 - val_Recall: 0.8633 - val_loss: 0.0536
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8633 - loss: 0.0431 - val_Recall: 0.8741 - val_loss: 0.0552
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8678 - loss: 0.0426 - val_Recall: 0.8741 - val_loss: 0.0562
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8896 - loss: 0.0377 - val_Recall: 0.8669 - val_loss: 0.0554
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8717 - loss: 0.0380 - val_Recall: 0.8741 - val_loss: 0.0555
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8908 - loss: 0.0368 - val_Recall: 0.8669 - val_loss: 0.0539
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8820 - loss: 0.0380 - val_Recall: 0.8597 - val_loss: 0.0544
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8650 - loss: 0.0411 - val_Recall: 0.8669 - val_loss: 0.0546
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8756 - loss: 0.0408 - val_Recall: 0.8597 - val_loss: 0.0542
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8516 - loss: 0.0441 - val_Recall: 0.8597 - val_loss: 0.0562
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8636 - loss: 0.0453 - val_Recall: 0.8597 - val_loss: 0.0552
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8510 - loss: 0.0446 - val_Recall: 0.8597 - val_loss: 0.0549

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  70.64911437034607

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_5 on the training and validation data.

# %%
model_5_train_perf = model_performance_classification(model_5,X_train,y_train)
model_5_train_perf
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy   Recall  Precision  F1 Score
# 0  0.993867  0.94754   0.993614  0.969304

# %%
model_5_val_perf = model_performance_classification(model_5,X_val,y_val)
model_5_val_perf
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9914  0.929433    0.98767  0.956465

# %%
y_train_pred_5 = model_5.predict(X_train)
y_val_pred_5 = model_5.predict(X_val)
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Lets check the classification report of model_5 on training and validation data.

# %%
print("Classification Report - Train data Model_2", end="\n\n")
cr_train_model_5 = classification_report(y_train,y_train_pred_5 > 0.5)
print(cr_train_model_5)
# Out:
# Classification Report - Train data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     14168
#          1.0       0.99      0.90      0.94       832
#
#     accuracy                           0.99     15000
#    macro avg       0.99      0.95      0.97     15000
# weighted avg       0.99      0.99      0.99     15000

# %%
print("Classification Report - Validation data Model_2", end="\n\n")
cr_val_model_5 = classification_report(y_val,y_val_pred_5 > 0.5)
print(cr_val_model_5)
# Out:
# Classification Report - Validation data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      4722
#          1.0       0.98      0.86      0.92       278
#
#     accuracy                           0.99      5000
#    macro avg       0.99      0.93      0.96      5000
# weighted avg       0.99      0.99      0.99      5000

# %% [markdown]
# ## Model 6

# %% [markdown]
# Let's see how does the model performance change when the model gives higher importance to the minority class

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
model_6 = Sequential()
model_6.add(Dense(32,activation="tanh",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_6.add(Dropout(.50)) # Complete the code to define the dropout rate
model_6.add(Dense(16,activation="tanh")) # Complete the code to define the number of neurons and activation function
model_6.add(Dense(8, activation = "tanh")) # Complete the code to define the number of neurons and activation function
model_6.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_6.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_40 (Dense)                │ (None, 32)             │         1,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,985 (7.75 KB)
#  Trainable params: 1,985 (7.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_3.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs,class_weight=cw_dict, ) # Complete the code such that the model is biased towards the minority class
end=time.time()
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.8863 - loss: 0.3448 - val_Recall: 0.8885 - val_loss: 0.0941
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.9335 - loss: 0.2505 - val_Recall: 0.8921 - val_loss: 0.1089
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9290 - loss: 0.2371 - val_Recall: 0.8921 - val_loss: 0.1008
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9161 - loss: 0.2882 - val_Recall: 0.8921 - val_loss: 0.0931
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9202 - loss: 0.2837 - val_Recall: 0.8849 - val_loss: 0.1068
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9213 - loss: 0.2959 - val_Recall: 0.8777 - val_loss: 0.1093
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9313 - loss: 0.2431 - val_Recall: 0.8813 - val_loss: 0.0958
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9236 - loss: 0.2581 - val_Recall: 0.8849 - val_loss: 0.0942
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9212 - loss: 0.2504 - val_Recall: 0.8957 - val_loss: 0.0990
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9217 - loss: 0.2892 - val_Recall: 0.8957 - val_loss: 0.1045
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9267 - loss: 0.2689 - val_Recall: 0.8885 - val_loss: 0.1088
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9181 - loss: 0.2992 - val_Recall: 0.8849 - val_loss: 0.1185
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9133 - loss: 0.3078 - val_Recall: 0.8885 - val_loss: 0.1031
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9158 - loss: 0.2966 - val_Recall: 0.8813 - val_loss: 0.1029
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9128 - loss: 0.3018 - val_Recall: 0.8885 - val_loss: 0.1127
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - Recall: 0.9221 - loss: 0.2914 - val_Recall: 0.8885 - val_loss: 0.1037
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9267 - loss: 0.2783 - val_Recall: 0.8957 - val_loss: 0.1220
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9174 - loss: 0.2917 - val_Recall: 0.8885 - val_loss: 0.1101
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9256 - loss: 0.2723 - val_Recall: 0.8885 - val_loss: 0.1015
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9277 - loss: 0.2630 - val_Recall: 0.8885 - val_loss: 0.1085
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9112 - loss: 0.3131 - val_Recall: 0.8885 - val_loss: 0.1124
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9269 - loss: 0.2692 - val_Recall: 0.8885 - val_loss: 0.1127
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9168 - loss: 0.2874 - val_Recall: 0.8885 - val_loss: 0.1034
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9014 - loss: 0.3259 - val_Recall: 0.8921 - val_loss: 0.0980
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9177 - loss: 0.2951 - val_Recall: 0.8921 - val_loss: 0.1057
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9331 - loss: 0.2645 - val_Recall: 0.8885 - val_loss: 0.1071
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9211 - loss: 0.2885 - val_Recall: 0.8921 - val_loss: 0.1012
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9373 - loss: 0.2667 - val_Recall: 0.8885 - val_loss: 0.0972
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9140 - loss: 0.2941 - val_Recall: 0.8885 - val_loss: 0.1007
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9227 - loss: 0.2625 - val_Recall: 0.8885 - val_loss: 0.1045
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9205 - loss: 0.2849 - val_Recall: 0.8885 - val_loss: 0.1049
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9225 - loss: 0.2668 - val_Recall: 0.8885 - val_loss: 0.1124
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9289 - loss: 0.2673 - val_Recall: 0.8849 - val_loss: 0.1096
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9238 - loss: 0.2657 - val_Recall: 0.8957 - val_loss: 0.1067
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9132 - loss: 0.2977 - val_Recall: 0.8849 - val_loss: 0.1024
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9396 - loss: 0.2304 - val_Recall: 0.8849 - val_loss: 0.1011
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9275 - loss: 0.2597 - val_Recall: 0.8921 - val_loss: 0.1070
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9206 - loss: 0.2861 - val_Recall: 0.8921 - val_loss: 0.0957
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9130 - loss: 0.2952 - val_Recall: 0.8813 - val_loss: 0.1017
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9238 - loss: 0.2540 - val_Recall: 0.8921 - val_loss: 0.1110
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9321 - loss: 0.2673 - val_Recall: 0.8957 - val_loss: 0.1092
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9182 - loss: 0.2854 - val_Recall: 0.8957 - val_loss: 0.1050
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9151 - loss: 0.2925 - val_Recall: 0.8921 - val_loss: 0.1030
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9048 - loss: 0.2755 - val_Recall: 0.8993 - val_loss: 0.1125
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9365 - loss: 0.2739 - val_Recall: 0.8957 - val_loss: 0.1088
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9028 - loss: 0.3062 - val_Recall: 0.8885 - val_loss: 0.1065
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9289 - loss: 0.2581 - val_Recall: 0.8813 - val_loss: 0.0986
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9283 - loss: 0.2566 - val_Recall: 0.8885 - val_loss: 0.1123
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9321 - loss: 0.2433 - val_Recall: 0.8885 - val_loss: 0.1023
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9141 - loss: 0.2917 - val_Recall: 0.8813 - val_loss: 0.1135

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  65.09321355819702

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_6 on training and validation data.

# %%
model_6_train_perf = model_performance_classification(model_6,X_train,y_train)
model_6_train_perf
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.3202  0.438195   0.484924  0.272178

# %%
model_6_val_perf = model_performance_classification(model_6,X_val,y_val)
model_6_val_perf
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy   Recall  Precision  F1 Score
# 0    0.3196  0.43665   0.484504  0.271722

# %%
y_train_pred_6 = model_6.predict(X_train)
y_val_pred_6 = model_6.predict(X_val)
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Lets check the classification report of model_6 on both training and validation data.

# %%
print("Classification Report - Train data Model_3", end="\n\n")
cr_train_model_6 = classification_report(y_train,y_train_pred_6 > 0.5)
print(cr_train_model_6)
# Out:
# Classification Report - Train data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.31      0.46     14168
#          1.0       0.05      0.57      0.09       832
#
#     accuracy                           0.32     15000
#    macro avg       0.48      0.44      0.27     15000
# weighted avg       0.88      0.32      0.44     15000

# %%
print("Classification Report - Validation data Model_3", end="\n\n")
cr_val_model_6 = classification_report(y_val,y_val_pred_6 > 0.5)
print(cr_val_model_6)
# Out:
# Classification Report - Validation data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.30      0.46      4722
#          1.0       0.05      0.57      0.08       278
#
#     accuracy                           0.32      5000
#    macro avg       0.48      0.44      0.27      5000
# weighted avg       0.87      0.32      0.44      5000

# %% [markdown]
# # **Model Performance Comparison and Final Model Selection**

# %% [markdown]
# Now, in order to select the final model, we will compare the performances of all the models for the training and test sets.

# %% [markdown]
# **Training Performance Comparison**

# %%
# training performance comparison

models_train_comp_df = pd.concat(
    [
        model_0_train_perf.T,
        model_1_train_perf.T,
        model_2_train_perf.T,
        model_3_train_perf.T,
        model_4_train_perf.T,
        model_5_train_perf.T,
        model_6_train_perf.T

    ],
    axis=1,
)
models_train_comp_df.columns = [
    "Model 0",
    "Model 1",
    "Model 2",
    "Model 3",
    "Model 4",
    "Model 5",
    "Model 6"
]
print("Training set performance comparison:")
models_train_comp_df
# Out:
# Training set performance comparison:
#             Model 0   Model 1   Model 2   Model 3   Model 4   Model 5  \
# Accuracy   0.987733  0.987667  0.986800  0.990800  0.993800  0.993867
# Recall     0.905262  0.901267  0.884404  0.956099  0.952030  0.947540
# Precision  0.974658  0.978385  0.988668  0.956099  0.988098  0.993614
# F1 Score   0.936872  0.936016  0.929547  0.956099  0.969282  0.969304
#
#             Model 6
# Accuracy   0.320200
# Recall     0.438195
# Precision  0.484924
# F1 Score   0.272178

# %% [markdown]
# **Validation Performance Comparison**

# %%
# Validation performance comparison

models_val_comp_df = pd.concat(
    [
        model_0_val_perf.T,
        model_1_val_perf.T,
        model_2_val_perf.T,
        model_3_val_perf.T,
        model_4_val_perf.T,
        model_5_val_perf.T,
        model_6_val_perf.T

    ],
    axis=1,
)
models_val_comp_df.columns = [
    "Model 0",
    "Model 1",
    "Model 2",
    "Model 3",
    "Model 4",
    "Model 5",
    "Model 6"
]
print("Validation set performance comparison:")
models_val_comp_df
# Out:
# Validation set performance comparison:
#             Model 0   Model 1   Model 2   Model 3   Model 4   Model 5  \
# Accuracy   0.987000  0.987200  0.988400  0.991400  0.991200  0.991400
# Recall     0.905098  0.906897  0.899069  0.944667  0.932712  0.929433
# Precision  0.967342  0.967560  0.989673  0.971931  0.981994  0.987670
# F1 Score   0.933710  0.934849  0.939178  0.957839  0.955853  0.956465
#
#             Model 6
# Accuracy   0.319600
# Recall     0.436650
# Precision  0.484504
# F1 Score   0.271722

# %% [markdown]
# **Checking the performance of the best model on the test set**

# %%
# best_model = model_0 ## Uncomment this line in case the best model is model_0
# best_model = model_1 ## Uncomment this line in case the best model is model_1
# best_model = model_2 ## Uncomment this line in case the best model is model_2
best_model = model_3 ## Uncomment this line in case the best model is model_3
# best_model = model_4 ## Uncomment this line in case the best model is model_4
# best_model = model_5 ## Uncomment this line in case the best model is model_5
# best_model = model_6 ## Uncomment this line in case the best model is model_6

# %%
# Test set performance for the best model
best_model_test_perf = model_performance_classification(best_model,X_test,y_test)
best_model_test_perf
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0     0.988  0.933627    0.95175  0.942477

# %%
y_test_pred_best = best_model.predict(X_test)

cr_test_best_model = classification_report(y_test, y_test_pred_best>0.5) # Check the classification report of best model on test data.
print(cr_test_best_model)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      4718
#          1.0       0.91      0.87      0.89       282
#
#     accuracy                           0.99      5000
#    macro avg       0.95      0.93      0.94      5000
# weighted avg       0.99      0.99      0.99      5000

# %% [markdown]
# # **Actionable Insights and Recommendations**

# %% [markdown]
# - Write down actionable insights here

# %% [markdown]
# - Write down business recommendations here
